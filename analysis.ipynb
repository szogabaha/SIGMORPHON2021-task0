# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
languages = ['afb','ail','ame','amh','ara','arz','aym','bra','bul','ces','ckb','ckt','cni','deu','evn','gup',
             'heb','ind','itl','kmr','kod','krl','lud','mag','nld','olo','pol','por','rus','sah','see','spa',
             'syc','tyv','vep']

# %%
def target_alphabet(df):
    tgt_alphabet = set()
    for lemma in df.infl:
        tgt_alphabet |= set(lemma)
    return tgt_alphabet

def source_alphabet(df):
    src_alphabet = set()
    for lemma in df.lemma:
        src_alphabet |= set(lemma)
    return src_alphabet

def merged_alphabet(df):
    merged_alphabet = set()
    for infl in df.infl:
        merged_alphabet |= set(infl)
    for lemma in df.lemma:
        merged_alphabet |= set(lemma)
    return merged_alphabet

def tags_combination(df):
    tags_combination = set()
    for token in df.tags:
            tags_combination.add(token)
    return tags_combination

def tags_of_df(df):
    tags = set()
    for token in df.tags:
            for tag in token.split(';'):
                tags.add(tag)
    return tags

def average_diff_between_lemma_and_infl(df):
    sum = 0
    #for i in range(len(df)):
    #    sum += abs(len(df.iloc[i].lemma)-len(df.iloc[i].infl))
    df['diff'] = df.apply(lambda x: abs(len(x.lemma)-len(x.infl)), axis=1)
    return df['diff'].sum() / len(df)

def average_lemma_len(df):
    df['lemma_len'] = df.apply(lambda x: len(x.lemma), axis=1)
    return df['lemma_len'].sum() / len(df)

def average_infl_len(df):
    df['infl_len'] = df.apply(lambda x: len(x.infl), axis=1)
    return df['infl_len'].sum() / len(df)


def analyse(datas):
    for lang in datas:
        df = pd.read_csv(lang+'.train',sep='\t', header=None, names=['lemma','infl','tags'])
        df = df.replace(np.nan, 'nan', regex=True)
        
        print(lang+':')
        print('\tLines:',len(df))
        #lines[lang] = len(df)
        #df['len'] = df.apply(lambda x : len(x.lemma), axis=1)

        print('\tTags len:', len(tags_of_df(df)))

        print('\tTags combination len:', len(tags_combination(df)))

        print('\tSource vocab len:', len(source_alphabet(df)))
        print('\tTarget vocab len:', len(target_alphabet(df)))
        print('\tMerged vocab len:', len(merged_alphabet(df)))

        print('\tUnique lemmas:', df.lemma.describe().unique()[1])
        
        #print('\tLongest lemma', max(map(len, df.lemma)))
        #print('\tShortest lemma', min(map(len, df.lemma)))

        print('\tAverage difference between lemma and infl:', average_diff_between_lemma_and_infl(df))
        
        print('\tAverage lemma len:', average_lemma_len(df))
        
        print('\tAverage infl len:', average_infl_len(df))

# %%
analyse(languages)
# Out:
# afb:
# 	Lines: 22165
# 	Tags len: 18
# 	Tags combination len: 68
# 	Source vocab len: 46
# 	Target vocab len: 39
# 	Merged vocab len: 46
# 	Unique lemmas: 5697
# 	Average difference between lemma and infl: 1.7637265959846604
# 	Average lemma len: 5.813850665463569
# 	Average infl len: 6.257207308820212
# ail:
# 	Lines: 918
# 	Tags len: 60
# 	Tags combination len: 240
# 	Source vocab len: 36
# 	Target vocab len: 42
# 	Merged vocab len: 44
# 	Unique lemmas: 470
# 	Average difference between lemma and infl: 4.147058823529412
# 	Average lemma len: 4.533769063180828
# 	Average infl len: 8.639433551198257
# ame:
# 	Lines: 2524
# 	Tags len: 21
# 	Tags combination len: 24
# 	Source vocab len: 26
# 	Target vocab len: 27
# 	Merged vocab len: 27
# 	Unique lemmas: 323
# 	Average difference between lemma and infl: 1.972662440570523
# 	Average lemma len: 8.375594294770206
# 	Average infl len: 9.025752773375594
# amh:
# 	Lines: 32254
# 	Tags len: 32
# 	Tags combination len: 123
# 	Source vocab len: 198
# 	Target vocab len: 229
# 	Merged vocab len: 229
# 	Unique lemmas: 2428
# 	Average difference between lemma and infl: 1.2899175296087306
# 	Average lemma len: 3.3086748930365224
# 	Average infl len: 4.595988094499907
# ara:
# 	Lines: 100027
# 	Tags len: 29
# 	Tags combination len: 442
# 	Source vocab len: 44
# 	Target vocab len: 44
# 	Merged vocab len: 46
# 	Unique lemmas: 2873
# 	Average difference between lemma and infl: 3.0716706489247905
# 	Average lemma len: 7.366760974536875
# 	Average infl len: 10.426154938166695
# arz:
# 	Lines: 17683
# 	Tags len: 18
# 	Tags combination len: 54
# 	Source vocab len: 43
# 	Target vocab len: 43
# 	Merged vocab len: 43
# 	Unique lemmas: 5702
# 	Average difference between lemma and infl: 1.405474184244755
# 	Average lemma len: 6.586608607136798
# 	Average infl len: 7.944918848611661
# aym:
# 	Lines: 100000
# 	Tags len: 38
# 	Tags combination len: 196
# 	Source vocab len: 22
# 	Target vocab len: 22
# 	Merged vocab len: 22
# 	Unique lemmas: 1507
# 	Average difference between lemma and infl: 5.6372
# 	Average lemma len: 7.11
# 	Average infl len: 12.73816
# bra:
# 	Lines: 1082
# 	Tags len: 20
# 	Tags combination len: 110
# 	Source vocab len: 58
# 	Target vocab len: 58
# 	Merged vocab len: 58
# 	Unique lemmas: 825
# 	Average difference between lemma and infl: 0.6987060998151571
# 	Average lemma len: 3.9630314232902033
# 	Average infl len: 4.659889094269871
# bul:
# 	Lines: 39011
# 	Tags len: 29
# 	Tags combination len: 95
# 	Source vocab len: 32
# 	Target vocab len: 32
# 	Merged vocab len: 32
# 	Unique lemmas: 2465
# 	Average difference between lemma and infl: 2.1207351772576963
# 	Average lemma len: 7.4173694598959266
# 	Average infl len: 9.492784086539693
# ces:
# 	Lines: 94169
# 	Tags len: 33
# 	Tags combination len: 194
# 	Source vocab len: 63
# 	Target vocab len: 65
# 	Merged vocab len: 65
# 	Unique lemmas: 5125
# 	Average difference between lemma and infl: 1.9287238900275037
# 	Average lemma len: 7.842612749418598
# 	Average infl len: 9.728116471450265
# ckb:
# 	Lines: 11577
# 	Tags len: 33
# 	Tags combination len: 200
# 	Source vocab len: 36
# 	Target vocab len: 36
# 	Merged vocab len: 36
# 	Unique lemmas: 253
# 	Average difference between lemma and infl: 3.4416515504880367
# 	Average lemma len: 5.420229765915177
# 	Average infl len: 8.838904724885548
# ckt:
# 	Lines: 132
# 	Tags len: 23
# 	Tags combination len: 29
# 	Source vocab len: 39
# 	Target vocab len: 39
# 	Merged vocab len: 39
# 	Unique lemmas: 118
# 	Average difference between lemma and infl: 1.1515151515151516
# 	Average lemma len: 8.803030303030303
# 	Average infl len: 9.757575757575758
# cni:
# 	Lines: 13948
# 	Tags len: 25
# 	Tags combination len: 93
# 	Source vocab len: 17
# 	Target vocab len: 17
# 	Merged vocab len: 17
# 	Unique lemmas: 406
# 	Average difference between lemma and infl: 3.6851878405506167
# 	Average lemma len: 8.87919414969888
# 	Average infl len: 11.252509320332663
# deu:
# 	Lines: 100000
# 	Tags len: 18
# 	Tags combination len: 37
# 	Source vocab len: 66
# 	Target vocab len: 67
# 	Merged vocab len: 67
# 	Unique lemmas: 11926
# 	Average difference between lemma and infl: 0.77482
# 	Average lemma len: 9.3376
# 	Average infl len: 9.85974
# evn:
# 	Lines: 5216
# 	Tags len: 73
# 	Tags combination len: 593
# 	Source vocab len: 35
# 	Target vocab len: 46
# 	Merged vocab len: 46
# 	Unique lemmas: 2919
# 	Average difference between lemma and infl: 3.589723926380368
# 	Average lemma len: 5.424271472392638
# 	Average infl len: 9.013995398773005
# gup:
# 	Lines: 214
# 	Tags len: 38
# 	Tags combination len: 121
# 	Source vocab len: 17
# 	Target vocab len: 17
# 	Merged vocab len: 17
# 	Unique lemmas: 62
# 	Average difference between lemma and infl: 6.5
# 	Average lemma len: 4.700934579439252
# 	Average infl len: 11.200934579439252
# heb:
# 	Lines: 23204
# 	Tags len: 24
# 	Tags combination len: 55
# 	Source vocab len: 40
# 	Target vocab len: 42
# 	Merged vocab len: 42
# 	Unique lemmas: 1183
# 	Average difference between lemma and infl: 2.792880537838304
# 	Average lemma len: 7.012670229270816
# 	Average infl len: 9.793052921910016
# ind:
# 	Lines: 11072
# 	Tags len: 24
# 	Tags combination len: 65
# 	Source vocab len: 24
# 	Target vocab len: 24
# 	Merged vocab len: 24
# 	Unique lemmas: 3614
# 	Average difference between lemma and infl: 4.417901011560693
# 	Average lemma len: 5.826138005780347
# 	Average infl len: 10.24403901734104
# itl:
# 	Lines: 1246
# 	Tags len: 77
# 	Tags combination len: 259
# 	Source vocab len: 34
# 	Target vocab len: 35
# 	Merged vocab len: 35
# 	Unique lemmas: 849
# 	Average difference between lemma and infl: 3.967094703049759
# 	Average lemma len: 4.62760834670947
# 	Average infl len: 8.594703049759229
# kmr:
# 	Lines: 100003
# 	Tags len: 26
# 	Tags combination len: 62
# 	Source vocab len: 81
# 	Target vocab len: 81
# 	Merged vocab len: 81
# 	Unique lemmas: 14417
# 	Average difference between lemma and infl: 2.185734427967161
# 	Average lemma len: 6.736807895763127
# 	Average infl len: 8.915162545123646
# kod:
# 	Lines: 323
# 	Tags len: 40
# 	Tags combination len: 42
# 	Source vocab len: 19
# 	Target vocab len: 20
# 	Merged vocab len: 20
# 	Unique lemmas: 65
# 	Average difference between lemma and infl: 2.7461300309597525
# 	Average lemma len: 5.95046439628483
# 	Average infl len: 8.6656346749226
# krl:
# 	Lines: 78673
# 	Tags len: 38
# 	Tags combination len: 166
# 	Source vocab len: 31
# 	Target vocab len: 32
# 	Merged vocab len: 32
# 	Unique lemmas: 1155
# 	Average difference between lemma and infl: 5.303471330697953
# 	Average lemma len: 7.893381465051543
# 	Average infl len: 13.13502726475411
# lud:
# 	Lines: 128
# 	Tags len: 28
# 	Tags combination len: 29
# 	Source vocab len: 28
# 	Target vocab len: 32
# 	Merged vocab len: 32
# 	Unique lemmas: 85
# 	Average difference between lemma and infl: 1.2421875
# 	Average lemma len: 6.25
# 	Average infl len: 7.2265625
# mag:
# 	Lines: 854
# 	Tags len: 32
# 	Tags combination len: 109
# 	Source vocab len: 59
# 	Target vocab len: 58
# 	Merged vocab len: 59
# 	Unique lemmas: 656
# 	Average difference between lemma and infl: 0.6487119437939111
# 	Average lemma len: 3.789227166276347
# 	Average infl len: 4.428571428571429
# nld:
# 	Lines: 38827
# 	Tags len: 19
# 	Tags combination len: 25
# 	Source vocab len: 55
# 	Target vocab len: 56
# 	Merged vocab len: 56
# 	Unique lemmas: 4969
# 	Average difference between lemma and infl: 1.1451309655651996
# 	Average lemma len: 8.7273031653231
# 	Average infl len: 9.156798104411878
# olo:
# 	Lines: 100062
# 	Tags len: 37
# 	Tags combination len: 318
# 	Source vocab len: 32
# 	Target vocab len: 35
# 	Merged vocab len: 35
# 	Unique lemmas: 3411
# 	Average difference between lemma and infl: 4.485878755171793
# 	Average lemma len: 9.109981811277008
# 	Average infl len: 13.559682996542143
# pol:
# 	Lines: 100039
# 	Tags len: 40
# 	Tags combination len: 655
# 	Source vocab len: 51
# 	Target vocab len: 52
# 	Merged vocab len: 52
# 	Unique lemmas: 1933
# 	Average difference between lemma and infl: 3.450344365697378
# 	Average lemma len: 9.750087465888303
# 	Average infl len: 13.169184018232889
# por:
# 	Lines: 100041
# 	Tags len: 22
# 	Tags combination len: 76
# 	Source vocab len: 33
# 	Target vocab len: 39
# 	Merged vocab len: 39
# 	Unique lemmas: 1884
# 	Average difference between lemma and infl: 1.7580791875331114
# 	Average lemma len: 8.043162303455583
# 	Average infl len: 9.629112064053738
# rus:
# 	Lines: 100002
# 	Tags len: 29
# 	Tags combination len: 101
# 	Source vocab len: 54
# 	Target vocab len: 54
# 	Merged vocab len: 54
# 	Unique lemmas: 8479
# 	Average difference between lemma and infl: 0.9131217375652487
# 	Average lemma len: 9.538209235815284
# 	Average infl len: 10.149457010859782
# sah:
# 	Lines: 100046
# 	Tags len: 35
# 	Tags combination len: 192
# 	Source vocab len: 37
# 	Target vocab len: 38
# 	Merged vocab len: 38
# 	Unique lemmas: 1410
# 	Average difference between lemma and infl: 6.4643663914599285
# 	Average lemma len: 6.671880934770006
# 	Average infl len: 13.136207344621473
# see:
# 	Lines: 3801
# 	Tags len: 13
# 	Tags combination len: 39
# 	Source vocab len: 25
# 	Target vocab len: 30
# 	Merged vocab len: 33
# 	Unique lemmas: 140
# 	Average difference between lemma and infl: 4.574059458037358
# 	Average lemma len: 6.280452512496711
# 	Average infl len: 10.82609839515917
# spa:
# 	Lines: 100001
# 	Tags len: 23
# 	Tags combination len: 70
# 	Source vocab len: 29
# 	Target vocab len: 34
# 	Merged vocab len: 34
# 	Unique lemmas: 2046
# 	Average difference between lemma and infl: 2.005949940500595
# 	Average lemma len: 8.44459555404446
# 	Average infl len: 10.24828751712483
# syc:
# 	Lines: 1217
# 	Tags len: 31
# 	Tags combination len: 276
# 	Source vocab len: 23
# 	Target vocab len: 31
# 	Merged vocab len: 32
# 	Unique lemmas: 534
# 	Average difference between lemma and infl: 6.154478225143796
# 	Average lemma len: 4.0262941659819225
# 	Average infl len: 10.146261298274446
# tyv:
# 	Lines: 100015
# 	Tags len: 33
# 	Tags combination len: 318
# 	Source vocab len: 36
# 	Target vocab len: 37
# 	Merged vocab len: 37
# 	Unique lemmas: 1257
# 	Average difference between lemma and infl: 6.721471779233115
# 	Average lemma len: 6.450962355646653
# 	Average infl len: 13.172414137879318
# vep:
# 	Lines: 100053
# 	Tags len: 39
# 	Tags combination len: 232
# 	Source vocab len: 34
# 	Target vocab len: 34
# 	Merged vocab len: 34
# 	Unique lemmas: 3978
# 	Average difference between lemma and infl: 3.6602200833558216
# 	Average lemma len: 8.511229048604239
# 	Average infl len: 12.103425184652135
